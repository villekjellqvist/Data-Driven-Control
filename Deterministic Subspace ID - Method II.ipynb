# %% [markdown]
# # Deterministic System Identification using Subspace Methods

# %% [markdown]
# ### Imports
#
# Note, for MIMO systems, package slycot must be installed as well.

# %%
import numpy as np
from scipy.linalg import sqrtm, schur
import matplotlib.pyplot as plt
import data_driven_control as cm
import control as ct
from matrepr import mdisplay, to_latex
from IPython.display import display, Latex, HTML

# %% [markdown]
# ***
#
# ### System
# Here, the true state space system $\Sigma$ is created. In reality, we wouldn't know this system or the matrices
# defining it. The system is defined as:
# $$
#     x[k+1] = Ax[k] + Bu \\
#     y[k] = Cx[k] + Du
# $$
# where $A \in \mathbb{R}^{n\times n}, B \in \mathbb{R}^{n\times p}, C \in \mathbb{R}^{q\times n}, D \in \mathbb{R}^{q\times p}$,\
# $x \in \mathbb{R}^{n\times 1}, u \in \mathbb{R}^{p\times 1}$ and $y \in \mathbb{R}^{q\times 1}$.\
# $n$ is the system order, $p$ the number of inputs and $q$ the number of outputs.

# %%
# %% System
A = np.array([[0,1,0,0],
              [-0.5,-0.4,0,-0.5],
              [0,0,0.2,-1],
              [0,0,0,-0.8]]
              )

B = np.array(
    [[0,0],
     [0,1],
     [0,0],
     [1,0]]
)
C = np.array(
    [[1,0,0,0],
     [0,0,2,0]]
    )
D = np.array([[0,0],[0,0]])

# %%
display(HTML(r'<h3>System Definition and stability </h3>'))

# This line will raise an error if state space is not
# appropriately dimensioned.
cm.check_state_space_dimensions(A, B, C, D)

display(Latex(r'$A = ' + to_latex(A) + '$, ' + r'$B = ' + to_latex(B) + '$'))
display(Latex(r'$C = ' + to_latex(C) + '$, ' + r'$D = ' + to_latex(D) + '$'))

# We will need the dimensions of the system later.
# p and q is known, but not n.
n = A.shape[0]
p = B.shape[1]
q = C.shape[0]

# Some sanity checks on the system.
truePoles = np.sort_complex(np.linalg.eigvals(A))

if np.all(np.abs(truePoles) < 1):
    stablestr = "A is stable."
else:
    stablestr = "A is not stable."
display(Latex(r'Notation: If the eigenvalues of $M$ are $\lambda_1, \lambda_2 \cdots \lambda_n$,' + 
            r' then $\text{Spectrum}(M) = \left[\lambda_1, \lambda_2 \cdots \lambda_n\right]$'))
display(Latex(rf'$\text{{Spectrum}}(A) = {to_latex(truePoles)} \Rightarrow $ {stablestr}'))
# Out:
# <h3>System Definition and stability </h3>
# $A = \left[\begin{array}{cccc}
#     0 & 1 & 0 & 0 \\
#     -0.5 & -0.4 & 0 & -0.5 \\
#     0 & 0 & 0.2 & -1 \\
#     0 & 0 & 0 & -0.8
# \end{array}\right]$, $B = \left[\begin{array}{cc}
#     0 & 0 \\
#     0 & 1 \\
#     0 & 0 \\
#     1 & 0
# \end{array}\right]$
# $C = \left[\begin{array}{cccc}
#     1 & 0 & 0 & 0 \\
#     0 & 0 & 2 & 0
# \end{array}\right]$, $D = \left[\begin{array}{cc}
#     0 & 0 \\
#     0 & 0
# \end{array}\right]$
# Notation: If the eigenvalues of $M$ are $\lambda_1, \lambda_2 \cdots \lambda_n$, then $\text{Spectrum}(M) = \left[\lambda_1, \lambda_2 \cdots \lambda_n\right]$
# $\text{Spectrum}(A) = \left[\begin{array}{cccc}
#     -0.8+0i & -0.2--0.6782i & -0.2+0.6782i & 0.2+0i
# \end{array}\right] \Rightarrow $ A is stable.

# %% [markdown]
# ***
#
# ### Checking controllability and observability

# %%
display(HTML(r'<h3>System Controllability and Observability </h3>'))

ctr = cm.make_controllability_matrix(A, B)
ctr_rank = np.linalg.matrix_rank(ctr)
ctr_str = fr"=n={n}\rightarrow$ Controllable" if ctr_rank==n else fr"<n={n}\rightarrow$ Not Controllable"
#mdisplay(ctr, title="'Controllability Matrix")
display(Latex(fr"$rank(\mathcal{{C}})={ctr_rank}" + ctr_str))

obs = cm.make_observability_matrix(A, C)
obs_rank = np.linalg.matrix_rank(obs)
obs_str = fr"=n={n}\rightarrow$ Observable" if obs_rank==n else fr"<n={n}\rightarrow$ Not Observable"
#mdisplay(obs, title="'Observability Matrix")
display(Latex(fr"$rank(\mathcal{{O}})={obs_rank}" + obs_str))
# Out:
# <h3>System Controllability and Observability </h3>
# $rank(\mathcal{C})=4=n=4\rightarrow$ Controllable
# $rank(\mathcal{O})=4=n=4\rightarrow$ Observable

# %% [markdown]
# ***
#
# ### Input-output data
# Here, we're gathering $N$ input-output data samples which will be used to identify the system. \
# White noise uniform is used as an input signal, for reasons that are explained in the next cell.

# %%
display(HTML(r'<h3> System Input-Output response </h3>'))

### Parameters for input data and system simulation.

# Nr of input samples.
N = 200
# Input signal(s).
# White noise usually makes for a well conditioned matrix.
u = np.random.uniform(-10, 10, size=(p,N))

true_sys = ct.ss(A,B,C,D,dt=True, name=r'$\Sigma$')
resp = ct.forced_response(true_sys,U=u)
resp.plot()
plt.plot();
# Out:
# <h3> System Input-Output response </h3>

# %% [markdown]
# ***
#
# ### Forming the Hankel Matrices
#
# Now, we use the input-output data to form the Hankel Matrices $U$ and $Y$ in the equation
#
# $$
# % Equation
# Y = \mathcal{O}_tX + \mathcal{T}_tU\\[2pt]
# \Updownarrow \\[4pt]
# % Y
# \underbrace{
#   \left[ \begin{array}{cccc}
#     y[0] & y[1] & \cdots & y[N-t-1] \\
#     y[1] & y[2] & \cdots & y[N-t]   \\
#     \vdots & \vdots & \ddots &  \\
#     y[t-1] & y[t] & \cdots & y[N-1]
#   \end{array} \right]
# }_Y
# % Ext. Obs.
# =
# \underbrace{
#   \left[ \begin{array}{c}
#     C \\ CA \\ \vdots \\ CA^{t-2}
#   \end{array} \right]
# }_{\mathcal{O}_t}
# % X
# \underbrace{
#   \left[ \begin{array}{cccc}
#     x[0] & x[1] & \cdots & x[N-1]
#   \end{array} \right]
# }_X
# % Toeplitz
# + \\[6pt] +
# \underbrace{
#   \left[ \begin{array}{cccc}
#     D & 0 & \cdots & 0 \\
#     CB & D & \cdots & 0 \\
#     \vdots & \vdots & \ddots & \\
#     CA^{t-3}B & CA^{t-4}B & \cdots & D
#   \end{array} \right]
# }_{\mathcal{T}_t}
# % U
# \underbrace{
#   \left[ \begin{array}{cccc}
#     u[0] & u[1] & \cdots & u[N-t-1] \\
#     u[1] & u[2] & \cdots & u[N-t]   \\
#     \vdots & \vdots & \ddots &  \\
#     u[t-1] & u[t] & \cdots & u[N-1]
#   \end{array} \right]
# }_U
# $$
#
# where $t$ denotes the number of block rows in the equation. \
# This is a free parameter but should be set such that $t, (N-t) > n$ and $t\times q < N$,
# so that $U$ and $Y$ are underdetermined matrices. In other words, they must have more rows than columns,
# and both the number of block rows and block columns must be greater than the system order $n$. Below, it is set so that $t = 2q$. \
# Furthermore, $u[t]$ must be persistently exciting, meaning $U$ must be of full rank. For this reason, random white noise is used for an input signal.

# %%
display(HTML(r'<h3> Input-output Hankel matrices </h3>'))
t_rows = int(N/(2*q))
U = cm.make_Hankel_matrix(u,t_rows,1,p)
Y = cm.make_Hankel_matrix(resp.y, t_rows, 1, q)

display(Latex('$U = ' + to_latex(U)+'$'))
display(Latex('$Y = ' + to_latex(Y)+'$'))
# Out:
# <h3> Input-output Hankel matrices </h3>
# $U = \left[\begin{array}{ccccccccccccccc}
#     8.379 & -0.4801 & -2.972 & -6.286 & 0.1488 & -9.17 & -7.528 & \dots & 5.517 & 7.352 & 5.205 & 1.202 & 4.011 & -4.448 & 6.186 \\
#     -0.9446 & -1.081 & -7.732 & 1.453 & 0.3837 & 3.109 & 7.75 & \dots & -7.968 & -2.336 & -9.706 & -9.024 & -9.553 & 4.277 & 1.214 \\
#     -0.4801 & -2.972 & -6.286 & 0.1488 & -9.17 & -7.528 & -9.14 & \dots & 7.352 & 5.205 & 1.202 & 4.011 & -4.448 & 6.186 & 8.53 \\
#     -1.081 & -7.732 & 1.453 & 0.3837 & 3.109 & 7.75 & 2.059 & \dots & -2.336 & -9.706 & -9.024 & -9.553 & 4.277 & 1.214 & 1.002 \\
#     -2.972 & -6.286 & 0.1488 & -9.17 & -7.528 & -9.14 & 0.4378 & \dots & 5.205 & 1.202 & 4.011 & -4.448 & 6.186 & 8.53 & 8.31 \\
#     \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
#     5.831 & 2.883 & 3.743 & 9.903 & 9.105 & -9.022 & 8.906 & \dots & -8.068 & 8.895 & -5.838 & -8.199 & -2.509 & -5.641 & 1.586 \\
#     -1.78 & 6.47 & -8.214 & -9.889 & 3.926 & 8.386 & 0.3079 & \dots & 5.932 & -8.731 & 6.618 & 3.922 & 1.556 & -9.898 & 9.651 \\
#     2.883 & 3.743 & 9.903 & 9.105 & -9.022 & 8.906 & 2.983 & \dots & 8.895 & -5.838 & -8.199 & -2.509 & -5.641 & 1.586 & 2.067 \\
#     6.47 & -8.214 & -9.889 & 3.926 & 8.386 & 0.3079 & -7.112 & \dots & -8.731 & 6.618 & 3.922 & 1.556 & -9.898 & 9.651 & 5.058 \\
#     3.743 & 9.903 & 9.105 & -9.022 & 8.906 & 2.983 & -8.192 & \dots & -5.838 & -8.199 & -2.509 & -5.641 & 1.586 & 2.067 & 5.861
# \end{array}\right]$
# $Y = \left[\begin{array}{ccccccccccccccc}
#     0 & 0 & -0.9446 & -4.893 & -1.711 & 3.196 & 4.214 & \dots & -3.277 & -1.321 & -10.17 & 3.126 & -10.14 & -5.724 & -3.443 \\
#     0 & 0 & -16.76 & 11.02 & -3.347 & 16.34 & -10.64 & \dots & 13.29 & -14.81 & -0.02341 & -17.06 & -0.1789 & -5.026 & -5.035 \\
#     0 & -0.9446 & -4.893 & -1.711 & 3.196 & 4.214 & -3.652 & \dots & -1.321 & -10.17 & 3.126 & -10.14 & -5.724 & -3.443 & 7.508 \\
#     0 & -16.76 & 11.02 & -3.347 & 16.34 & -10.64 & 27.34 & \dots & -14.81 & -0.02341 & -17.06 & -0.1789 & -5.026 & -5.035 & 11.11 \\
#     -0.9446 & -4.893 & -1.711 & 3.196 & 4.214 & -3.652 & 14.47 & \dots & -10.17 & 3.126 & -10.14 & -5.724 & -3.443 & 7.508 & 2.962 \\
#     \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
#     6.416 & 0.3908 & 9.702 & -2.198 & -10.07 & 22.12 & 4.896 & \dots & 6.6 & -8.298 & 9.202 & -18.71 & 30.16 & -34.33 & 17.58 \\
#     -0.5756 & 2.524 & 4.567 & -0.3802 & 5.365 & 13.18 & -16.86 & \dots & 5.428 & -9.531 & 12.71 & -11.29 & -1.56 & -6.328 & 3.781 \\
#     0.3908 & 9.702 & -2.198 & -10.07 & 22.12 & 4.896 & -7.252 & \dots & -8.298 & 9.202 & -18.71 & 30.16 & -34.33 & 17.58 & -19.15 \\
#     2.524 & 4.567 & -0.3802 & 5.365 & 13.18 & -16.86 & 7.001 & \dots & -9.531 & 12.71 & -11.29 & -1.56 & -6.328 & 3.781 & -2.43 \\
#     9.702 & -2.198 & -10.07 & 22.12 & 4.896 & -7.252 & -11.64 & \dots & 9.202 & -18.71 & 30.16 & -34.33 & 17.58 & -19.15 & 34.1
# \end{array}\right]$

# %% [markdown]
# ***
#
# ### Extracting $\mathcal{\hat{O}}_t$, estimating system matrices ${\hat{A}}$ and $\hat{C}$
# Next, we're calculating the projection of the nullspace of $U$, $\Pi_U^{\perp}$
# $$
# \begin{align*}
# \Pi_U^{\perp} &= I - U^{\dagger}U \\
# U\Pi_U^{\perp} &= 0 = U - \underbrace{UU^{\dagger}}_{I}U, \:
# \text{(Holds if $U$ is full rank and underdetermined.)}
# \end{align*}
# $$
# We then right-multiply this projection with $Y = \mathcal{O}_tX + \mathcal{T}_tU$ to remove the right term and get $G=\mathcal{O}_tX \Pi_U^{\perp}$
# $$
# G = Y\Pi_U^{\perp} = \mathcal{O}_tX \Pi_U^{\perp} + \mathcal{T}_tU \Pi_U^{\perp} = \mathcal{O}_tX \Pi_U^{\perp} + 0
# $$
# With the right term removed, we need to factor $G$ into its components $\mathcal{O}_t$ and $X \Pi_U^{\perp}$. \
# We do this by taking the singular value decomposition of $G$
# $$
# G = U_G S_G V^T_G \\
# S_G = \left[ \begin{array}{ccc}
#     \sigma_1 & & 0 \\
#      & \ddots & \\
#     0 & & \sigma_{\hat{n}}
# \end{array} \right], \: \text{$\hat{n}$ is the estimated system order}
# $$
# $\hat{\mathcal{O}}_t$ can now be obtained with the ansatz:
# $$
# G = U_G S_G V^T_G = \underbrace{U_G (S_G)^{\frac{1}{2}}}_{\hat{\mathcal{O}}_t} \underbrace{(S_G)^{\frac{1}{2}}V^T_G}_{X\Pi_U^{\perp}}
# $$
# While the equation $Y = \mathcal{O}_tX + \mathcal{T}_tU$ in no way has a unique solution given $U$ and $Y$, it does not matter. \
# The estimated system matrices that we will get are not likely to be the same as the true
# system matrices. \
# If the input-output data is good however, they should be related to a
# similar system $\hat{\Sigma}$ through the relations:
# $$
#   \hat{A} = T^{-1}AT, \hat{B} = T^{-1}B, \hat{C} = CT, \hat{D} = D
# $$
# where T is an invertible similarity matrix. $\hat{\Sigma}$ will have the same input-output relation and poles as the original system $\Sigma$.
# <br>
# <br>
# With $\hat{\mathcal{O}}_t$ in hand, we can get $\hat{A}$ and $\hat{C}$.
# We construct two new matrices from $\hat{\mathcal{O}}_t$.
#
# $$
# \hat{\mathcal{O}}_{0,t-1} =
#   \left[ \begin{array}{c}
#     \hat{C} \\ \hat{C}\hat{A} \\ \vdots \\ \hat{C}\hat{A}^{t-3}
#   \end{array} \right], \:
# \hat{\mathcal{O}}_{1,t} =
#   \left[ \begin{array}{c}
#     \hat{C}\hat{A} \\ \hat{C}\hat{A}^2 \\ \vdots \\ \hat{C}\hat{A}^{t-2} =
#   \end{array} \right]
#   = \hat{\mathcal{O}}_{0,t-1}\hat{A}
# $$
# We get $\hat{C}$ directly from the first $q$ rows of $\mathcal{O}_{0,t-1}$, and $\hat{A}$ from
# $$
# \hat{\mathcal{O}}_{1,t} = \hat{\mathcal{O}}_{0,t-1}\hat{A} \Leftrightarrow \hat{A} = \hat{\mathcal{O}}_{0,t-1}^{\dagger} \hat{\mathcal{O}}_{1,t}
# $$
# The cell below finds $\hat{A}$ and $\hat{C}$ with the above described method, and displays the eigenvalues of $A$ and $\hat{A}$ for a quick visual inspection.

# %%
display(HTML(r'<h3>Comparison of true and estimated system eigenvalues </h3>'))

# Finding G from Y by multiplying with null space of U
PI_U = np.eye(U.shape[1]) - np.linalg.pinv(U)@U
G = Y@PI_U

# Taking the SVD of G
U_G, s_G, Vh_G = np.linalg.svd(G)
s_G_cutoff = s_G[s_G > np.max(s_G)*1e-3]
n_hat = s_G_cutoff.size
S_G = np.diag(s_G_cutoff)

# Getting the extended observability matrix, estimating A and C
Obs = (U_G[:,:n_hat]@sqrtm(S_G))
Obs_1 = Obs[:-q,:]
Obs_2 = Obs[q:,:]
A_hat = np.linalg.pinv(Obs_1)@Obs_2
C_hat = Obs[0:q, :n_hat]

# Visual inspection of poles
truePoles = np.sort_complex(np.linalg.eigvals(A))
estPoles = np.sort_complex(np.linalg.eigvals(A_hat))
display(Latex(rf'$\text{{Spectrum}}(A) = {to_latex(truePoles)}$'))
display(Latex(rf'$\text{{Spectrum}}(\hat{{A}}) = {to_latex(estPoles)}$'))
# Out:
# <h3>Comparison of true and estimated system eigenvalues </h3>
# $\text{Spectrum}(A) = \left[\begin{array}{cccc}
#     -0.8+0i & -0.2--0.6782i & -0.2+0.6782i & 0.2+0i
# \end{array}\right]$
# $\text{Spectrum}(\hat{A}) = \left[\begin{array}{cccc}
#     -0.8+0i & -0.2--0.6782i & -0.2+0.6782i & 0.2+0i
# \end{array}\right]$

# %% [markdown]
# ***
#
# ### Estimating $\hat{B}$ and $\hat{D}$
# $\newcommand{\vecT}[1]{{\text{vec}({#1})}}$
# With $\hat{A}$ and $\hat{C}$ in hand, $\hat{B}$ and $\hat{D}$ now have a unique solution. \
# Getting to it requires some linear algebra though. Starting with the solution for a discrete time state space:
# $$
# x[k] = A^t x[0] + \sum_{k = 0}^{t-1} A^{t-k-1} Bu[k] \\
# y[k] = CA^t x[0] + \sum_{k = 0}^{t-1} CA^{t-k-1} Bu[k] + Du[t]
# $$
# These equations need to be reworked such that the fitting parameters $x0, B$ and $D$ can be factored out.
# To achieve this, there are two useful formulations using the
# [Kronecker product $\otimes$](https://en.wikipedia.org/wiki/Vectorization_(mathematics)#Compatibility_with_Kronecker_products).
# $$
# \vecT{CA^{t-k-1} Bu[k]} = (u^T[k] \otimes CA^{t-k-1})\vecT{B} \\
# \vecT{Du[t]} = (u^T[t] \otimes I_q) \vecT{D}
# $$
# where $\vecT{M}$ is the operation of 'stacking' all column vectors of $M$ into a single column vector. \
# Since all of the terms in the state space solution are already column vectors, this is not something we need to care about.
# $y[k]$ can now be rewritten as:
# $$
# y[k] = CA^t x[0] + \sum_{k = 0}^{t-1} (u^T[k] \otimes CA^{t-k-1})\vecT{B} + (u^T[t] \otimes I_q) \vecT{D} \\
# =
#   \left[ \begin{array}{ccc}
#     {CA^t} & \sum_{k = 0}^{t-1}(u^T[k] \otimes CA^{t-k-1}) & (u^T[t] \otimes I_q)
#   \end{array} \right]
#   \left[ \begin{array}{c}
#     x[0] \\ \vecT{B} \\ \vecT{D}
#   \end{array} \right] \\
#   =
#   \underbrace{
#     \left[ \begin{array}{ccc}
#       \phi_{t,1} & \phi_{t,2} & \phi_{t,3}
#     \end{array} \right]
#   }_{\phi_t}
#   \left[ \begin{array}{c}
#     x[0] \\ \vecT{B} \\ \vecT{D}
#   \end{array} \right]
# $$
# giving us the least squares formulation:
# $$
# \left[ \begin{array}{c}
#   y[0] \\ y[1] \\ \vdots \\ y[t-1]
# \end{array} \right]
# =
# \left[ \begin{array}{ccc}
#   \phi_{0,1} & \phi_{0,2} & \phi_{0,3} \\
#   \phi_{1,1} & \phi_{1,2} & \phi_{1,3} \\
#   & \vdots & \\
#   \phi_{t-1,1} & \phi_{t-1,2} & \phi_{t-1,3}
# \end{array} \right]
# \left[ \begin{array}{c}
#   \hat{x}[0] \\ \vecT{\hat{B}} \\ \vecT{\hat{D}}
# \end{array} \right]
# $$
# Now, $\hat{B}$ and $\hat{D}$ can easily be found, meaning we have estimated the full system
# $\hat{\Sigma}.$ Below, the cell output shows the least squares total residual error and all the
# estimated state space matrices.

# %%
display(HTML(r'<h3> Least Squares Fitting B and D </h3>'))
# Constructing Phi

Phi_1 = cm.make_observability_matrix(A_hat, C_hat, N)
Phi_2 = np.zeros((q*N,p*n))
Phi_3 = np.zeros((q*N,q*p))
for t in range(0,N):
    Phi_3[q*t:q*(t+1),:] = np.kron(np.reshape(u[:,t],[1,p]),np.eye(q))
    for k in range(0,t):
        Phi_2[q*t:q*(t+1),:] += np.kron(np.reshape(u[:,k],(1,p)),C_hat@np.linalg.matrix_power(A_hat,t-k-1))
Phi = np.concatenate([Phi_1, Phi_2, Phi_3],axis=1)

# Least Squares fit of x0, vec(B) and vec(C)
y = cm.interleave_vectors(*resp.y)
params, res = np.linalg.lstsq(Phi,y)[0:2]
display(Latex(fr'$\hat{{B}},\hat{{D}}$ fitting done with a total residual error of ${res[0]}$.'))

# Extracting B and D from ls fit of Phi
B_hat = np.reshape(params[n:-q*p],(n,p),order='F')
D_hat = np.reshape(params[-q*p:],(q,p),order='F')

# Displaying the estimated matrices.
display(Latex(r'$\hat{A} = ' + to_latex(A_hat) + '$, ' + r'$\hat{B} = ' + to_latex(B_hat) + '$'))
display(Latex(r'$\hat{C} = ' + to_latex(C_hat) + '$, ' + r'$\hat{D} = ' + to_latex(D_hat) + '$'))
# Out:
# <h3> Least Squares Fitting B and D </h3>
# $\hat{B},\hat{D}$ fitting done with a total residual error of $2.444599564147476e-26$.
# $\hat{A} = \left[\begin{array}{cccc}
#     -0.8517 & -0.2721 & 0.01376 & -0.1233 \\
#     0.1564 & -0.05767 & 0.1804 & 0.4001 \\
#     0.06396 & -0.7165 & -0.01291 & 0.5748 \\
#     0.1592 & 0.06394 & -0.4915 & -0.0777
# \end{array}\right]$, $\hat{B} = \left[\begin{array}{cc}
#     -0.1647 & -0.0142 \\
#     -0.1618 & 0.06137 \\
#     0.01553 & -0.02044 \\
#     -0.04902 & -0.1226
# \end{array}\right]$
# $\hat{C} = \left[\begin{array}{cccc}
#     2.278 & -2.851 & -7.131 & -0.5024 \\
#     -7.386 & 5.937 & -2.878 & 4.308
# \end{array}\right]$, $\hat{D} = \left[\begin{array}{cc}
#     -1.109 \times 10^{-16} & 1.414 \times 10^{-17} \\
#     3.327 \times 10^{-18} & 9.857 \times 10^{-17}
# \end{array}\right]$

# %% [markdown]
# ***
#
# ### Testing the estimated system
# Now, all that's left is to test the estimated system and see if it has the same
# input-output relations as the true system, which is done below.

# %%
display(HTML(r'<h3> Forced Response Comparison of True and Estimated System </h3>'))

# Creating the estimated system and test signals.
est_sys = ct.ss(A_hat,B_hat,C_hat,D_hat,dt=True,name=r'$\hat{\Sigma}$')
testN = 50
ttest = np.linspace(0,100,testN)
rngu = np.zeros((1,testN))
for i in range(1,testN):
    rngu[0,i] = rngu[0,i-1] + np.random.normal(0,1)
utest = np.concatenate([rngu, np.cos(ttest*(6*np.pi)/100).reshape((1,testN))], axis=0)

# Plotting the forced response for the test signals.
ct.forced_response(true_sys, U=utest).plot(linewidth=3);
ct.forced_response(est_sys, U=utest).plot(linestyle='--', color='r');
# Out:
# <h3> Forced Response Comparison of True and Estimated System </h3>
